# %% [markdown]
# # Training Machine Learning Model File
# ## This file contains the code which is used to train the machine learning model
# ## After the model is trained the weight of the model get saved with its best accuracy
#
# # **Code Reference**
# ## https://github.com/debayanmitra1993-data/Blindness-Detection-Diabetic-Retinopathy-/blob/master/3_resnet50(colab).ipynb

# %%
import numpy as np
import cv2
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from multiprocessing.pool import ThreadPool
import pickle
import multiprocessing
import seaborn as sns
plt.rcParams["axes.grid"] = False
from PIL import Image
from tqdm import tqdm
from prettytable import PrettyTable

# TensorFlow and tf.keras Imports
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model, model_from_json
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dropout, Dense, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import applications, optimizers, Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical

# Sklearn Imports
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, cohen_kappa_score, accuracy_score

# %matplotlib inline

# %% [markdown]
# # The Functions
# the program uses various functions to deal with different activties throughout in order to successfully train the machine learning model

# %%
#This Function loads the train/test data from a folder and cvs file into variables
def load_data():
    train = pd.read_csv('train.csv')
    test = pd.read_csv('test.csv')
    
    train_dir = os.path.join('./','train_images/')
    test_dir = os.path.join('./','test_images/')
    
    train['file_path'] = train['id_code'].map(lambda x: os.path.join(train_dir,'{}.png'.format(x)))
    test['file_path'] = test['id_code'].map(lambda x: os.path.join(test_dir,'{}.png'.format(x)))
    
    train['file_name'] = train["id_code"].apply(lambda x: x + ".png")
    test['file_name'] = test["id_code"].apply(lambda x: x + ".png")
    
    train['diagnosis'] = train['diagnosis'].astype(str)
    
    return train,test

# %% [markdown]
# These next Functions deal with Processing The Images to produce an results of higher accuracy

# %%
'''Function loads an image from Folder , Resizes and saves in another directory '''

def image_resize_save(directory, output_directory, filenames):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory, exist_ok=True)
    for filename in tqdm(filenames):
        output_filepath = os.path.join(output_directory, filename)
        # Check if the resized image already exists
        if not os.path.exists(output_filepath):
            input_filepath = os.path.join(directory, filename)
            img = cv2.imread(input_filepath)
            if img is not None:
                resized_img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                cv2.imwrite(output_filepath, resized_img)
            else:
                print(f"Warning: '{input_filepath}' cannot be read.")
        else:
            print(f"Skipping existing file: {output_filepath}")

# %%
#Function to crop image background
def crop_image_from_gray(img,tol=7):
    if img.ndim ==2:
        mask = img>tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    elif img.ndim==3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img>tol
        
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): # if image is too dark and we crop out everything,
            return img # return original image
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
            img = np.stack([img1,img2,img3],axis=-1)
        return img
    
    
#function provides circle crop on the image
def circle_crop(img, sigmaX = 30):   
    img = crop_image_from_gray(img)    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    height, width, depth = img.shape    
    
    x = int(width/2)
    y = int(height/2)
    r = np.amin((x,y))
    
    circle_img = np.zeros((height, width), np.uint8)
    cv2.circle(circle_img, (x,y), int(r), 1, thickness=-1)
    img = cv2.bitwise_and(img, img, mask=circle_img)
    img = crop_image_from_gray(img)
    img=cv2.addWeighted(img,4, cv2.GaussianBlur( img , (0,0) , sigmaX) ,-4 ,128)
    return img 

def preprocess_image(input_directory, output_directory, filenames):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory, exist_ok=True)
    for filename in filenames: 
        input_filepath = os.path.join(input_directory, filename)
        output_filepath = os.path.join(output_directory, filename)
        # Check if the preprocessed image already exists
        if not os.path.exists(output_filepath):
            img = cv2.imread(input_filepath)
            if img is not None:
                height, width, channels = img.shape
                img = circle_crop(img)  # Assuming circle_crop is your preprocessing step
                cv2.imwrite(output_filepath, cv2.resize(img, (IMG_SIZE, IMG_SIZE)))
            else:
                print(f"Warning: '{input_filepath}' cannot be read.")
        else:
            print(f"Skipping existing file: {output_filepath}")

# %% [markdown]
# Next Functions are used to successfully train the model

# %%
def img_generator(df_train, df_test):
    train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2, horizontal_flip=True)
    
    train_generator = train_datagen.flow_from_dataframe(
        dataframe=df_train,
        directory="./train_images_resized_preprocessed/",
        x_col="file_name",
        y_col="diagnosis",
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        target_size=(HEIGHT, WIDTH),
        subset='training'
    )
    
    valid_generator = train_datagen.flow_from_dataframe(
        dataframe=df_train,
        directory="./train_images_resized_preprocessed/",
        x_col="file_name",
        y_col="diagnosis",
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        target_size=(HEIGHT, WIDTH),
        subset='validation'
    )
    
    test_datagen = ImageDataGenerator(rescale=1./255)
    
    test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    directory="D:\\DR_ML\\backend\\test_images_resized_preprocessed\\",
    x_col="file_name",
    target_size=(HEIGHT, WIDTH),
    batch_size=1,
    shuffle=False,
    class_mode=None
)


    return train_generator, valid_generator, test_generator

print("Calling img_generator")
train_generator, valid_generator, test_generator = img_generator(df_train, df_test)
print("img_generator called successfully")
# Out:
# Calling img_generator
# Found 2930 validated image filenames belonging to 5 classes.
# Found 732 validated image filenames belonging to 5 classes.
# Found 1928 validated image filenames.
# img_generator called successfully

# %%
#this function create the resnet50 model with iniall imagenet weights without the top layer 
def create_model(input_shape, n_out):
    input_tensor = Input(shape=input_shape)
    base_model = applications.ResNet50(weights="imagenet", include_top=False,input_tensor=input_tensor)

    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_output = Dense(n_out, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    return model

# %% [markdown]
# Main code of the program underneath declaring variables and using the functions to process the images and train the model

# %%
#Declearing important variables 
IMG_SIZE = 512
BATCH_SIZE = 8
EPOCHS = 25
WARMUP_EPOCHS = 2
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
HEIGHT = 320
WIDTH = 320
CANAL = 3
#variables used for callbacks
ES_PATIENCE = 5
RLROP_PATIENCE = 3
DECAY_DROP = 0.5

# %%
#load in the directories 
train_dir = "train_images/"
val_dir   = "backend/test_images/" #directories for training

test_dir  = "backend/val/" #directory for final model scoring

# %%
# Assuming you've defined preprocess_image similarly to image_resize_save

# Load data into dataframes
df_train, df_test = load_data()
print(df_train.shape, df_test.shape, '\n')

# Resize training images
image_resize_save('./train_images', './train_images_resized', df_train['file_name'].values)
# Preprocess training images - Ensure this function processes images from './train_images_resized' and saves to './train_images_resized_preprocessed'
preprocess_image('./train_images_resized', './train_images_resized_preprocessed', df_train['file_name'].values)

# Optionally, resize test images if not done previously, then preprocess
image_resize_save('./test_images', './test_images_resized', df_test['file_name'].values)
preprocess_image('./test_images_resized', './test_images_resized_preprocessed', df_test['file_name'].values)

# Display first few rows of test DataFrame to verify
df_test.head(6)
# Out:
# (3662, 4) (1928, 3)
#  67%|██████▋   | 2456/3662 [00:00<00:00, 12310.66it/s]
# Skipping existing file: ./train_images_resized\000c1434d8d7.png
# Skipping existing file: ./train_images_resized\001639a390f0.png
# Skipping existing file: ./train_images_resized\0024cdab0c1e.png
# Skipping existing file: ./train_images_resized\002c21358ce6.png
# Skipping existing file: ./train_images_resized\005b95c28852.png
# Skipping existing file: ./train_images_resized\0083ee8054ee.png
# Skipping existing file: ./train_images_resized\0097f532ac9f.png
# Skipping existing file: ./train_images_resized\00a8624548a9.png
# Skipping existing file: ./train_images_resized\00b74780d31d.png
# Skipping existing file: ./train_images_resized\00cb6555d108.png
# Skipping existing file: ./train_images_resized\00cc2b75cddd.png
# Skipping existing file: ./train_images_resized\00e4ddff966a.png
# Skipping existing file: ./train_images_resized\00f6c1be5a33.png
# Skipping existing file: ./train_images_resized\0104b032c141.png
# Skipping existing file: ./train_images_resized\0124dffecf29.png
# Skipping existing file: ./train_images_resized\0125fbd2e791.png
# Skipping existing file: ./train_images_resized\012a242ac6ff.png
# Skipping existing file: ./train_images_resized\014508ccb9cb.png
# Skipping existing file: ./train_images_resized\0151781fe50b.png
# Skipping existing file: ./train_images_resized\0161338f53cc.png
# Skipping existing file: ./train_images_resized\0180bfa26c0b.png
# Skipping existing file: ./train_images_resized\0182152c50de.png
# Skipping existing file: ./train_images_resized\01b3aed3ed4c.png
# Skipping existing file: ./train_images_resized\01c7808d901d.png
# Skipping existing file: ./train_images_resized\01d9477b1171.png
# Skipping existing file: ./train_images_resized\01eb826f6467.png
# Skipping existing file: ./train_images_resized\01f7bb8be950.png
# Skipping existing file: ./train_images_resized\0212dd31f623.png
# Skipping existing file: ./train_images_resized\022f820027b8.png
# Skipping existing file: ./train_images_resized\0231642cf1c2.png
# Skipping existing file: ./train_images_resized\0232dfea7547.png
# Skipping existing file: ./train_images_resized\02358b47ea89.png
# Skipping existing file: ./train_images_resized\0243404e8a00.png
# Skipping existing file: ./train_images_resized\025a169a0bb0.png
# Skipping existing file: ./train_images_resized\02685f13cefd.png
# Skipping existing file: ./train_images_resized\026dcd9af143.png
# Skipping existing file: ./train_images_resized\02cd34a85b24.png
# Skipping existing file: ./train_images_resized\02da652c74b8.png
# Skipping existing file: ./train_images_resized\02dda30d3acf.png
# Skipping existing file: ./train_images_resized\0304bedad8fe.png
# Skipping existing file: ./train_images_resized\0318598cfd16.png
# Skipping existing file: ./train_images_resized\032d7b0b4bf6.png
# Skipping existing file: ./train_images_resized\033f2b43de6d.png
# Skipping existing file: ./train_images_resized\034cb07a550f.png
# Skipping existing file: ./train_images_resized\03676c71ed1b.png
# Skipping existing file: ./train_images_resized\0369f3efe69b.png
# Skipping existing file: ./train_images_resized\03747397839f.png
# Skipping existing file: ./train_images_resized\03a7f4a5786f.png
# Skipping existing file: ./train_images_resized\03b373718013.png
# Skipping existing file: ./train_images_resized\03c85870824c.png
# Skipping existing file: ./train_images_resized\03e25101e8e8.png
# Skipping existing file: ./train_images_resized\03fd50da928d.png
# Skipping existing file: ./train_images_resized\03ff7d159f10.png
# Skipping existing file: ./train_images_resized\0415fc68b176.png
# Skipping existing file: ./train_images_resized\041f09eec1e8.png
# Skipping existing file: ./train_images_resized\0423237770a7.png
# Skipping existing file: ./train_images_resized\042470a92154.png
# Skipping existing file: ./train_images_resized\04579e31e4be.png
# Skipping existing file: ./train_images_resized\04a6fc58dabc.png
# Skipping existing file: ./train_images_resized\04ac765f91a1.png
# Skipping existing file: ./train_images_resized\04aef84a2cc1.png
# Skipping existing file: ./train_images_resized\04d029cfb612.png
# Skipping existing file: ./train_images_resized\04efb1a284cc.png
# Skipping existing file: ./train_images_resized\050bb1eafa76.png
# Skipping existing file: ./train_images_resized\05113073b268.png
# Skipping existing file: ./train_images_resized\05195a3db5e2.png
# Skipping existing file: ./train_images_resized\0519b934f6b1.png
# Skipping existing file: ./train_images_resized\052d9a3fe55a.png
# Skipping existing file: ./train_images_resized\05339950962e.png
# Skipping existing file: ./train_images_resized\054b1b305160.png
# Skipping existing file: ./train_images_resized\0551676cc2aa.png
# Skipping existing file: ./train_images_resized\059bc89df7f4.png
# Skipping existing file: ./train_images_resized\05a5183c92d0.png
# Skipping existing file: ./train_images_resized\05b1bb2bdb81.png
# Skipping existing file: ./train_images_resized\05cd0178ccfe.png
# Skipping existing file: ./train_images_resized\05e9126dfa5c.png
# Skipping existing file: ./train_images_resized\06024377d573.png
# Skipping existing file: ./train_images_resized\060e00d1e2ab.png
# Skipping existing file: ./train_images_resized\064af6592ba6.png
# Skipping existing file: ./train_images_resized\06586082a24d.png
# Skipping existing file: ./train_images_resized\0684311afdfc.png
# Skipping existing file: ./train_images_resized\069f43616fab.png
# Skipping existing file: ./train_images_resized\06b71823f9cd.png
# Skipping existing file: ./train_images_resized\06be1092a062.png
# Skipping existing file: ./train_images_resized\07083738b75e.png
# Skipping existing file: ./train_images_resized\0709652336e2.png
# Skipping existing file: ./train_images_resized\070d4ce5fd90.png
# Skipping existing file: ./train_images_resized\070f67572d03.png
# Skipping existing file: ./train_images_resized\07122e268a1d.png
# Skipping existing file: ./train_images_resized\071435a218ec.png
# Skipping existing file: ./train_images_resized\07419eddd6be.png
# Skipping existing file: ./train_images_resized\07596907347b.png
# Skipping existing file: ./train_images_resized\0773a1c326ad.png
# Skipping existing file: ./train_images_resized\07751b94a88a.png
# Skipping existing file: ./train_images_resized\0790515cf5af.png
# Skipping existing file: ./train_images_resized\07929d32b5b3.png
# Skipping existing file: ./train_images_resized\07a0be6b347f.png
# Skipping existing file: ./train_images_resized\07a0e34c8d20.png
# Skipping existing file: ./train_images_resized\07a1c7073982.png
# Skipping existing file: ./train_images_resized\07a2b8cabf6b.png
# Skipping existing file: ./train_images_resized\07a3be30563b.png
# Skipping existing file: ./train_images_resized\07d8db76b301.png
# Skipping existing file: ./train_images_resized\07e827469099.png
# Skipping existing file: ./train_images_resized\07f5d7baf907.png
# Skipping existing file: ./train_images_resized\08037e4490e5.png
# Skipping existing file: ./train_images_resized\080ee76c958c.png
# Skipping existing file: ./train_images_resized\080f66eedfb9.png
# Skipping existing file: ./train_images_resized\084c02cf077f.png
# Skipping existing file: ./train_images_resized\0851d6a69589.png
# Skipping existing file: ./train_images_resized\086d41d17da8.png
# Skipping existing file: ./train_images_resized\08752092140d.png
# Skipping existing file: ./train_images_resized\08a3875063c3.png
# Skipping existing file: ./train_images_resized\08b6e3240858.png
# Skipping existing file: ./train_images_resized\08bef347f40d.png
# Skipping existing file: ./train_images_resized\08c17a2d95b7.png
# Skipping existing file: ./train_images_resized\08c60c647673.png
# Skipping existing file: ./train_images_resized\08ee569d4721.png
# Skipping existing file: ./train_images_resized\08f8838d69bb.png
# Skipping existing file: ./train_images_resized\09237bf783a4.png
# Skipping existing file: ./train_images_resized\0924cec998fa.png
# Skipping existing file: ./train_images_resized\093a42649c29.png
# Skipping existing file: ./train_images_resized\093cf723fede.png
# Skipping existing file: ./train_images_resized\094858f005ab.png
# Skipping existing file: ./train_images_resized\0953c0ac1735.png
# Skipping existing file: ./train_images_resized\096436d68d06.png
# Skipping existing file: ./train_images_resized\09662e462531.png
# Skipping existing file: ./train_images_resized\0981195eb9fb.png
# Skipping existing file: ./train_images_resized\099021fac3c9.png
# Skipping existing file: ./train_images_resized\09934421c79e.png
# Skipping existing file: ./train_images_resized\09935d72892b.png
# Skipping existing file: ./train_images_resized\09c8323c612e.png
# Skipping existing file: ./train_images_resized\09eeafa9656a.png
# Skipping existing file: ./train_images_resized\09f1111a388a.png
# Skipping existing file: ./train_images_resized\09f6ab477654.png
# Skipping existing file: ./train_images_resized\0a09aa7356c0.png
# Skipping existing file: ./train_images_resized\0a1076183736.png
# Skipping existing file: ./train_images_resized\0a3202889f4d.png
# Skipping existing file: ./train_images_resized\0a38b552372d.png
# Skipping existing file: ./train_images_resized\0a4e1a29ffff.png
# Skipping existing file: ./train_images_resized\0a61bddab956.png
# Skipping existing file: ./train_images_resized\0a74c92e287c.png
# Skipping existing file: ./train_images_resized\0a85a1e8f9e9.png
# Skipping existing file: ./train_images_resized\0a902c80d5da.png
# Skipping existing file: ./train_images_resized\0a9ec1e99ce4.png
# Skipping existing file: ./train_images_resized\0abf0c485f66.png
# Skipping existing file: ./train_images_resized\0ac436400db4.png
# Skipping existing file: ./train_images_resized\0ad7f631dedb.png
# Skipping existing file: ./train_images_resized\0ada12c0e78f.png
# Skipping existing file: ./train_images_resized\0ae2dd2e09ea.png
# Skipping existing file: ./train_images_resized\0af296d2f04a.png
# Skipping existing file: ./train_images_resized\0afbeeef0ff7.png
# Skipping existing file: ./train_images_resized\0afdfe5f422c.png
# Skipping existing file: ./train_images_resized\0b00f8a77510.png
# Skipping existing file: ./train_images_resized\0b2ea8f268cf.png
# Skipping existing file: ./train_images_resized\0b3efe669365.png
# Skipping existing file: ./train_images_resized\0b64a0a06f9a.png
# Skipping existing file: ./train_images_resized\0b8bdec9d869.png
# Skipping existing file: ./train_images_resized\0babc12807b2.png
# Skipping existing file: ./train_images_resized\0bf37ca3156a.png
# Skipping existing file: ./train_images_resized\0c2e2369dfff.png
# Skipping existing file: ./train_images_resized\0c38940e1f80.png
# Skipping existing file: ./train_images_resized\0c43c79e8cfb.png
# Skipping existing file: ./train_images_resized\0c55d58bebaf.png
# Skipping existing file: ./train_images_resized\0c76fd494af6.png
# Skipping existing file: ./train_images_resized\0c7e82daf5a0.png
# Skipping existing file: ./train_images_resized\0c917c372572.png
# Skipping existing file: ./train_images_resized\0ca0aee4d57e.png
# Skipping existing file: ./train_images_resized\0cae727cf119.png
# Skipping existing file: ./train_images_resized\0cb14014117d.png
# Skipping existing file: ./train_images_resized\0cb6b898389f.png
# Skipping existing file: ./train_images_resized\0cbcc7b23613.png
# Skipping existing file: ./train_images_resized\0cd31078cd08.png
# Skipping existing file: ./train_images_resized\0ce062f26edc.png
# Skipping existing file: ./train_images_resized\0ceb222f6629.png
# Skipping existing file: ./train_images_resized\0cecc2864b7f.png
# Skipping existing file: ./train_images_resized\0d0a21fd354f.png
# Skipping existing file: ./train_images_resized\0d0b8fc9ab5c.png
# Skipping existing file: ./train_images_resized\0d310aba6373.png
# Skipping existing file: ./train_images_resized\0d744aed4d64.png
# Skipping existing file: ./train_images_resized\0d8f60ed9280.png
# Skipping existing file: ./train_images_resized\0d9a9896f801.png
# Skipping existing file: ./train_images_resized\0da09e3ce8f1.png
# Skipping existing file: ./train_images_resized\0da321efbce6.png
# Skipping existing file: ./train_images_resized\0da632ca45e0.png
# Skipping existing file: ./train_images_resized\0daddc45d832.png
# Skipping existing file: ./train_images_resized\0db1d8dcf219.png
# Skipping existing file: ./train_images_resized\0dbaa09a458c.png
# Skipping existing file: ./train_images_resized\0dbe6c26cedc.png
# Skipping existing file: ./train_images_resized\0dc031c94225.png
# Skipping existing file: ./train_images_resized\0dc8d25b3f69.png
# Skipping existing file: ./train_images_resized\0dce95217626.png
# Skipping existing file: ./train_images_resized\0e0003ddd8df.png
# Skipping existing file: ./train_images_resized\0e0fc1d9810c.png
# Skipping existing file: ./train_images_resized\0e3572b5884a.png
# Skipping existing file: ./train_images_resized\0e43c8298fc0.png
# Skipping existing file: ./train_images_resized\0e75d51152fc.png
# Skipping existing file: ./train_images_resized\0e82bcacc475.png
# Skipping existing file: ./train_images_resized\0e94cd271c00.png
# Skipping existing file: ./train_images_resized\0eb52045349f.png
# Skipping existing file: ./train_images_resized\0eced86c9db8.png
# Skipping existing file: ./train_images_resized\0edadb2aa127.png
# Skipping existing file: ./train_images_resized\0ef4c61dc056.png
# Skipping existing file: ./train_images_resized\0efc93ec838b.png
# Skipping existing file: ./train_images_resized\0eff8eacb2f7.png
# Skipping existing file: ./train_images_resized\0f364b7d4384.png
# Skipping existing file: ./train_images_resized\0f495d87656a.png
# Skipping existing file: ./train_images_resized\0f6e645466a2.png
# Skipping existing file: ./train_images_resized\0f882877bf13.png
# Skipping existing file: ./train_images_resized\0f96c358a250.png
# Skipping existing file: ./train_images_resized\0fb1053285cf.png
# Skipping existing file: ./train_images_resized\0fb560f9adb2.png
# Skipping existing file: ./train_images_resized\0fbbd665431f.png
# Skipping existing file: ./train_images_resized\0fc6829da85b.png
# Skipping existing file: ./train_images_resized\0fcfc6301f3d.png
# Skipping existing file: ./train_images_resized\0fd16b64697e.png
# Skipping existing file: ./train_images_resized\0fe31196e0e8.png
# Skipping existing file: ./train_images_resized\0fffa73e2402.png
# Skipping existing file: ./train_images_resized\1002b5151b8e.png
# Skipping existing file: ./train_images_resized\1002f3fe38f0.png
# Skipping existing file: ./train_images_resized\1006345f70b7.png
# Skipping existing file: ./train_images_resized\101b9ebfc720.png
# Skipping existing file: ./train_images_resized\103abbd8b63e.png
# Skipping existing file: ./train_images_resized\103f97a2ab15.png
# Skipping existing file: ./train_images_resized\107aea0d9289.png
# Skipping existing file: ./train_images_resized\10a5026eb8e6.png
# Skipping existing file: ./train_images_resized\10bf25731c08.png
# Skipping existing file: ./train_images_resized\10de500cf0c5.png
# Skipping existing file: ./train_images_resized\10ecc5292ab1.png
# Skipping existing file: ./train_images_resized\10eefba568dd.png
# Skipping existing file: ./train_images_resized\10f10fd30718.png
# Skipping existing file: ./train_images_resized\10f36b0239fb.png
# Skipping existing file: ./train_images_resized\10f6ef37fe43.png
# Skipping existing file: ./train_images_resized\10fca1abf338.png
# Skipping existing file: ./train_images_resized\1116271db4ea.png
# Skipping existing file: ./train_images_resized\111898ab463d.png
# Skipping existing file: ./train_images_resized\1120f6d08d95.png
# Skipping existing file: ./train_images_resized\11242a67122d.png
# Skipping existing file: ./train_images_resized\1124ffcd76c2.png
# Skipping existing file: ./train_images_resized\115e42dd6a81.png
# Skipping existing file: ./train_images_resized\1177d583c807.png
# Skipping existing file: ./train_images_resized\11b220a397b8.png
# Skipping existing file: ./train_images_resized\11b5c77fbf79.png
# Skipping existing file: ./train_images_resized\11d8e5eaee5b.png
# Skipping existing file: ./train_images_resized\12025b34deb8.png
# Skipping existing file: ./train_images_resized\12058bbb8299.png
# Skipping existing file: ./train_images_resized\1269ab57c2e6.png
# Skipping existing file: ./train_images_resized\12a82fc7d73e.png
# Skipping existing file: ./train_images_resized\12ab2f6397f0.png
# Skipping existing file: ./train_images_resized\12ae44be0d38.png
# Skipping existing file: ./train_images_resized\12b57dac703e.png
# Skipping existing file: ./train_images_resized\12bc439d373a.png
# Skipping existing file: ./train_images_resized\12ce6a1a1f31.png
# Skipping existing file: ./train_images_resized\12e3f5f2cb17.png
# Skipping existing file: ./train_images_resized\12e6e66c80a7.png
# Skipping existing file: ./train_images_resized\12ef75375322.png
# Skipping existing file: ./train_images_resized\13063d1bc4ea.png
# Skipping existing file: ./train_images_resized\13073f075a56.png
# Skipping existing file: ./train_images_resized\135575dc57c9.png
# Skipping existing file: ./train_images_resized\13ab8db8c700.png
# Skipping existing file: ./train_images_resized\13c191b59ed0.png
# Skipping existing file: ./train_images_resized\13d014ccd136.png
# Skipping existing file: ./train_images_resized\13d411c85ffd.png
# Skipping existing file: ./train_images_resized\13d71389563f.png
# Skipping existing file: ./train_images_resized\1409ab48175a.png
# Skipping existing file: ./train_images_resized\1411c8ab7161.png
# Skipping existing file: ./train_images_resized\1414128bead0.png
# Skipping existing file: ./train_images_resized\141735b57ec0.png
# Skipping existing file: ./train_images_resized\1438288bb2e1.png
# Skipping existing file: ./train_images_resized\143db89c11c8.png
# Skipping existing file: ./train_images_resized\144a1a426137.png
# Skipping existing file: ./train_images_resized\144b01e7b993.png
# Skipping existing file: ./train_images_resized\14515b8f19b6.png
# Skipping existing file: ./train_images_resized\14c3b41d289c.png
# Skipping existing file: ./train_images_resized\14e3f84445f7.png
# Skipping existing file: ./train_images_resized\14ee87d6cc42.png
# Skipping existing file: ./train_images_resized\1509d097b69a.png
# Skipping existing file: ./train_images_resized\150f92b45349.png
# Skipping existing file: ./train_images_resized\150fc7127582.png
# Skipping existing file: ./train_images_resized\152db3de8120.png
# Skipping existing file: ./train_images_resized\1541226c5d72.png
# Skipping existing file: ./train_images_resized\15528e740543.png
# Skipping existing file: ./train_images_resized\155e2df6bfcf.png
# Skipping existing file: ./train_images_resized\157d17349cc6.png
# Skipping existing file: ./train_images_resized\1594ca6c30d3.png
# Skipping existing file: ./train_images_resized\15b21c80cc31.png
# Skipping existing file: ./train_images_resized\15bed5adde74.png
# Skipping existing file: ./train_images_resized\15c24478ac72.png
# Skipping existing file: ./train_images_resized\15cc2aef772a.png
# Skipping existing file: ./train_images_resized\15cd5f52d300.png
# Skipping existing file: ./train_images_resized\15e24b73d4a7.png
# Skipping existing file: ./train_images_resized\15e96e848b46.png
# Skipping existing file: ./train_images_resized\15f440753916.png
# Skipping existing file: ./train_images_resized\15f8d769935c.png
# Skipping existing file: ./train_images_resized\1601c939412f.png
# Skipping existing file: ./train_images_resized\16060f05d047.png
# Skipping existing file: ./train_images_resized\1608c82a263f.png
# Skipping existing file: ./train_images_resized\1623e8e3adc4.png
# Skipping existing file: ./train_images_resized\1632c4311fc9.png
# Skipping existing file: ./train_images_resized\1633f8291a80.png
# Skipping existing file: ./train_images_resized\1638404f385c.png
# Skipping existing file: ./train_images_resized\164cd5a3a6cd.png
# Skipping existing file: ./train_images_resized\165634a6167e.png
# Skipping existing file: ./train_images_resized\165c548185f8.png
# Skipping existing file: ./train_images_resized\165cd2070ebd.png
# Skipping existing file: ./train_images_resized\166068a24416.png
# Skipping existing file: ./train_images_resized\16ce555748d8.png
# Skipping existing file: ./train_images_resized\17188c13e635.png
# Skipping existing file: ./train_images_resized\172df1330a60.png
# Skipping existing file: ./train_images_resized\174db0854291.png
# Skipping existing file: ./train_images_resized\175dd560810a.png
# Skipping existing file: ./train_images_resized\1782142e17d9.png
# Skipping existing file: ./train_images_resized\178412895d5e.png
# Skipping existing file: ./train_images_resized\17d7d6b092f4.png
# Skipping existing file: ./train_images_resized\17d997fe1090.png
# Skipping existing file: ./train_images_resized\17e6116b89b3.png
# Skipping existing file: ./train_images_resized\17eb5d4ad740.png
# Skipping existing file: ./train_images_resized\17eff993386f.png
# Skipping existing file: ./train_images_resized\17f6c7072f61.png
# Skipping existing file: ./train_images_resized\180afe1d5ef7.png
# Skipping existing file: ./train_images_resized\18323d8f2470.png
# Skipping existing file: ./train_images_resized\1844a039b4ea.png
# Skipping existing file: ./train_images_resized\184a185e7447.png
# Skipping existing file: ./train_images_resized\18621b9ca978.png
# Skipping existing file: ./train_images_resized\1864d3411143.png
# Skipping existing file: ./train_images_resized\186c1835eec5.png
# Skipping existing file: ./train_images_resized\187f6ccda87a.png
# Skipping existing file: ./train_images_resized\188219f2d9c6.png
# Skipping existing file: ./train_images_resized\188a9323be03.png
# Skipping existing file: ./train_images_resized\1891698febce.png
# Skipping existing file: ./train_images_resized\189cbbc9e5e3.png
# Skipping existing file: ./train_images_resized\18af532e7e1e.png
# Skipping existing file: ./train_images_resized\18b06f56ab27.png
# Skipping existing file: ./train_images_resized\18b7e34eab8f.png
# Skipping existing file: ./train_images_resized\18b99159a14f.png
# Skipping existing file: ./train_images_resized\18cde9649e90.png
# Skipping existing file: ./train_images_resized\18ce0cdc473d.png
# Skipping existing file: ./train_images_resized\18d8fdb140b7.png
# Skipping existing file: ./train_images_resized\18f1f979d30d.png
# Skipping existing file: ./train_images_resized\190a309f2cc5.png
# Skipping existing file: ./train_images_resized\19113e5f45ec.png
# Skipping existing file: ./train_images_resized\191348830ddf.png
# Skipping existing file: ./train_images_resized\191a711852bd.png
# Skipping existing file: ./train_images_resized\191cf5668f33.png
# Skipping existing file: ./train_images_resized\19244004583f.png
# Skipping existing file: ./train_images_resized\1943983492e5.png
# Skipping existing file: ./train_images_resized\194814669fee.png
# Skipping existing file: ./train_images_resized\19545647508e.png
# Skipping existing file: ./train_images_resized\1968183f0e61.png
# Skipping existing file: ./train_images_resized\196e6a186452.png
# Skipping existing file: ./train_images_resized\19722bff5a09.png
# Skipping existing file: ./train_images_resized\197af0de76e2.png
# Skipping existing file: ./train_images_resized\19b0e3c734f5.png
# Skipping existing file: ./train_images_resized\19e350c7c83c.png
# Skipping existing file: ./train_images_resized\19ef4d292196.png
# Skipping existing file: ./train_images_resized\1a03a7970337.png
# Skipping existing file: ./train_images_resized\1a0dbc6c0cda.png
# Skipping existing file: ./train_images_resized\1a19f2ef4472.png
# Skipping existing file: ./train_images_resized\1a1b4b2450ca.png
# Skipping existing file: ./train_images_resized\1a1e974a7dbf.png
# Skipping existing file: ./train_images_resized\1a369baf9ee6.png
# Skipping existing file: ./train_images_resized\1a7e3356b39c.png
# Skipping existing file: ./train_images_resized\1a90fad9ffa2.png
# Skipping existing file: ./train_images_resized\1ab3f1c71a5f.png
# Skipping existing file: ./train_images_resized\1ab8d3431ffc.png
# Skipping existing file: ./train_images_resized\1ade1e949383.png
# Skipping existing file: ./train_images_resized\1ae3c58759fb.png
# Skipping existing file: ./train_images_resized\1ae8c165fd53.png
# Skipping existing file: ./train_images_resized\1b329a127307.png
# Skipping existing file: ./train_images_resized\1b32e1d775ea.png
# Skipping existing file: ./train_images_resized\1b3647865779.png
# Skipping existing file: ./train_images_resized\1b398c0494d1.png
# Skipping existing file: ./train_images_resized\1b4625877527.png
# Skipping existing file: ./train_images_resized\1b495ac025b7.png
# Skipping existing file: ./train_images_resized\1b862fb6f65d.png
# Skipping existing file: ./train_images_resized\1b8701231c8f.png
# Skipping existing file: ./train_images_resized\1b8ad0afe9fb.png
# Skipping existing file: ./train_images_resized\1bb0ddfe753a.png
# Skipping existing file: ./train_images_resized\1bea04b2bb2d.png
# Skipping existing file: ./train_images_resized\1bf30c84bbad.png
# Skipping existing file: ./train_images_resized\1c0cf251b426.png
# Skipping existing file: ./train_images_resized\1c0e5dd1b14c.png
# Skipping existing file: ./train_images_resized\1c13a1483f4a.png
# Skipping existing file: ./train_images_resized\1c3a6b4449e9.png
# Skipping existing file: ./train_images_resized\1c47815f4a6b.png
# Skipping existing file: ./train_images_resized\1c4d87baaffc.png
# Skipping existing file: ./train_images_resized\1c4f3aa4df06.png
# Skipping existing file: ./train_images_resized\1c578b72d7b3.png
# Skipping existing file: ./train_images_resized\1c5ad36fb799.png
# Skipping existing file: ./train_images_resized\1c5e6cdc7ee1.png
# Skipping existing file: ./train_images_resized\1c6d119c3d70.png
# Skipping existing file: ./train_images_resized\1c7a013eeba7.png
# Skipping existing file: ./train_images_resized\1c9521878baf.png
# Skipping existing file: ./train_images_resized\1c9c583c10bf.png
# Skipping existing file: ./train_images_resized\1ca35d483772.png
# Skipping existing file: ./train_images_resized\1ca62b3e4fd3.png
# Skipping existing file: ./train_images_resized\1ca91751be4d.png
# Skipping existing file: ./train_images_resized\1caba2fb38f6.png
# Skipping existing file: ./train_images_resized\1cb6961d141c.png
# Skipping existing file: ./train_images_resized\1cb814ed6332.png
# Skipping existing file: ./train_images_resized\1cc58b15f466.png
# Skipping existing file: ./train_images_resized\1d0b93317aa8.png
# Skipping existing file: ./train_images_resized\1d11794057ff.png
# Skipping existing file: ./train_images_resized\1d14dd912671.png
# Skipping existing file: ./train_images_resized\1d2472849dce.png
# Skipping existing file: ./train_images_resized\1d29cb2f4296.png
# Skipping existing file: ./train_images_resized\1d37f1c8b6d8.png
# Skipping existing file: ./train_images_resized\1d3e9b939732.png
# Skipping existing file: ./train_images_resized\1d46f1326394.png
# Skipping existing file: ./train_images_resized\1d55e689cf84.png
# Skipping existing file: ./train_images_resized\1d674e2e32e0.png
# Skipping existing file: ./train_images_resized\1d74c4713e21.png
# Skipping existing file: ./train_images_resized\1da25637859b.png
# Skipping existing file: ./train_images_resized\1da4a17c18c9.png
# Skipping existing file: ./train_images_resized\1db0393cdbc1.png
# Skipping existing file: ./train_images_resized\1db18bdd43aa.png
# Skipping existing file: ./train_images_resized\1db6bb46c102.png
# Skipping existing file: ./train_images_resized\1dbdc32c17db.png
# Skipping existing file: ./train_images_resized\1dd9adcbfff4.png
# Skipping existing file: ./train_images_resized\1df0431bfa73.png
# Skipping existing file: ./train_images_resized\1df0a4c23c95.png
# Skipping existing file: ./train_images_resized\1df1530b9b8d.png
# Skipping existing file: ./train_images_resized\1df3e03a8f5f.png
# Skipping existing file: ./train_images_resized\1dfbede13143.png
# Skipping existing file: ./train_images_resized\1dfe599d12a9.png
# Skipping existing file: ./train_images_resized\1e036f2e7095.png
# Skipping existing file: ./train_images_resized\1e143fa3de57.png
# Skipping existing file: ./train_images_resized\1e1fb019710d.png
# Skipping existing file: ./train_images_resized\1e4650743fa2.png
# Skipping existing file: ./train_images_resized\1e4b3b823b95.png
# Skipping existing file: ./train_images_resized\1e742358e0b9.png
# Skipping existing file: ./train_images_resized\1e7ccd4a1c87.png
# Skipping existing file: ./train_images_resized\1e8a1fdee5b9.png
# Skipping existing file: ./train_images_resized\1e8c31e29dd3.png
# Skipping existing file: ./train_images_resized\1e9224ccca95.png
# Skipping existing file: ./train_images_resized\1ec95179cdfe.png
# Skipping existing file: ./train_images_resized\1ee1eb7943db.png
# Skipping existing file: ./train_images_resized\1ee355480567.png
# Skipping existing file: ./train_images_resized\1eee55494271.png
# Skipping existing file: ./train_images_resized\1efa5d443707.png
# Skipping existing file: ./train_images_resized\1f07dae3cadb.png
# Skipping existing file: ./train_images_resized\1f0e223b8055.png
# Skipping existing file: ./train_images_resized\1f15ca672675.png
# Skipping existing file: ./train_images_resized\1f31701dd61b.png
# Skipping existing file: ./train_images_resized\1f3f32efaf20.png
# Skipping existing file: ./train_images_resized\1f4bf8e28b41.png
# Skipping existing file: ./train_images_resized\1f4fb37e0854.png
# Skipping existing file: ./train_images_resized\1f543a86c4d4.png
# Skipping existing file: ./train_images_resized\1f5496352859.png
# Skipping existing file: ./train_images_resized\1f63d44d9e3c.png
# Skipping existing file: ./train_images_resized\1f9ccda4ddf2.png
# Skipping existing file: ./train_images_resized\1faf8664816c.png
# Skipping existing file: ./train_images_resized\1fb455685328.png
# Skipping existing file: ./train_images_resized\1fd5d860d4d7.png
# Skipping existing file: ./train_images_resized\1fddd7c98fd2.png
# Skipping existing file: ./train_images_resized\1ffaa51a6245.png
# Skipping existing file: ./train_images_resized\200d947f75db.png
# Skipping existing file: ./train_images_resized\2017cd92c63d.png
# Skipping existing file: ./train_images_resized\201f6e10c108.png
# Skipping existing file: ./train_images_resized\201f882365d3.png
# Skipping existing file: ./train_images_resized\203275daf46d.png
# Skipping existing file: ./train_images_resized\20404ec7b518.png
# Skipping existing file: ./train_images_resized\20688cb25704.png
# Skipping existing file: ./train_images_resized\207a580de0ea.png
# Skipping existing file: ./train_images_resized\207dd0487264.png
# Skipping existing file: ./train_images_resized\20c883d3bd38.png
# Skipping existing file: ./train_images_resized\20d5fdd450ae.png
# Skipping existing file: ./train_images_resized\20f86e068276.png
# Skipping existing file: ./train_images_resized\21037f5c7790.png
# Skipping existing file: ./train_images_resized\210bfe0127c6.png
# Skipping existing file: ./train_images_resized\211518c46162.png
# Skipping existing file: ./train_images_resized\2131aa3a1e6f.png
# Skipping existing file: ./train_images_resized\215d2b7c3fde.png
# Skipping existing file: ./train_images_resized\217dad18a5ed.png
# Skipping existing file: ./train_images_resized\218c822a3dd9.png
# Skipping existing file: ./train_images_resized\21abd36095a1.png
# Skipping existing file: ./train_images_resized\21d18b022429.png
# Skipping existing file: ./train_images_resized\22098b1fe461.png
# Skipping existing file: ./train_images_resized\2209daf71aab.png
# Skipping existing file: ./train_images_resized\2221cf5c7935.png
# Skipping existing file: ./train_images_resized\222d0ac042b4.png
# Skipping existing file: ./train_images_resized\222f3ee3a1e8.png
# Skipping existing file: ./train_images_resized\22325552a4e3.png
# Skipping existing file: ./train_images_resized\2241b7e90782.png
# Skipping existing file: ./train_images_resized\22449af52060.png
# Skipping existing file: ./train_images_resized\224bb938e2dd.png
# Skipping existing file: ./train_images_resized\224c14366e11.png
# Skipping existing file: ./train_images_resized\226c6ceb9185.png
# Skipping existing file: ./train_images_resized\22895c89792f.png
# Skipping existing file: ./train_images_resized\22a6da005395.png
# Skipping existing file: ./train_images_resized\22ce8ef69357.png
# Skipping existing file: ./train_images_resized\22d843b2bbd1.png
# Skipping existing file: ./train_images_resized\23148a40ecb0.png
# Skipping existing file: ./train_images_resized\23175b7ef453.png
# Skipping existing file: ./train_images_resized\232549883508.png
# Skipping existing file: ./train_images_resized\233d948e2544.png
# Skipping existing file: ./train_images_resized\234399352d36.png
# Skipping existing file: ./train_images_resized\236f56771ec6.png
# Skipping existing file: ./train_images_resized\2376e5415458.png
# Skipping existing file: ./train_images_resized\237aa50edc34.png
# Skipping existing file: ./train_images_resized\237c078d00fc.png
# Skipping existing file: ./train_images_resized\2399d68d407f.png
# Skipping existing file: ./train_images_resized\239f2c348ea4.png
# Skipping existing file: ./train_images_resized\23d7ca170bdb.png
# Skipping existing file: ./train_images_resized\23fca0693e2a.png
# Skipping existing file: ./train_images_resized\2408799a09b2.png
# Skipping existing file: ./train_images_resized\240b25a7debe.png
# Skipping existing file: ./train_images_resized\242fc19be06f.png
# Skipping existing file: ./train_images_resized\2463bb04ebc3.png
# Skipping existing file: ./train_images_resized\246e4506824a.png
# Skipping existing file: ./train_images_resized\247ac63e5510.png
# Skipping existing file: ./train_images_resized\247e98aba610.png
# Skipping existing file: ./train_images_resized\248139c423c4.png
# Skipping existing file: ./train_images_resized\248dec89b3a2.png
# Skipping existing file: ./train_images_resized\24b87f744598.png
# Skipping existing file: ./train_images_resized\24b943fe725e.png
# Skipping existing file: ./train_images_resized\24de56d433cd.png
# Skipping existing file: ./train_images_resized\24f271c87e73.png
# Skipping existing file: ./train_images_resized\24f3e70f0419.png
# Skipping existing file: ./train_images_resized\25002fe43f92.png
# Skipping existing file: ./train_images_resized\252305189b3a.png
# Skipping existing file: ./train_images_resized\2532613a584a.png
# Skipping existing file: ./train_images_resized\253e96488cfb.png
# Skipping existing file: ./train_images_resized\254052cf3e48.png
# Skipping existing file: ./train_images_resized\2585bbc91909.png
# Skipping existing file: ./train_images_resized\259d30f693b6.png
# Skipping existing file: ./train_images_resized\25a0a1e41afd.png
# Skipping existing file: ./train_images_resized\25b0e72705a8.png
# Skipping existing file: ./train_images_resized\25b4080f598b.png
# Skipping existing file: ./train_images_resized\25d069089c5e.png
# Skipping existing file: ./train_images_resized\25dc1b41ed9c.png
# Skipping existing file: ./train_images_resized\25e9fd872182.png
# Skipping existing file: ./train_images_resized\2608e1dac5b1.png
# Skipping existing file: ./train_images_resized\260a455692b5.png
# Skipping existing file: ./train_images_resized\261c6bd63bff.png
# Skipping existing file: ./train_images_resized\2628305cbb29.png
# Skipping existing file: ./train_images_resized\262ad704319c.png
# Skipping existing file: ./train_images_resized\263d8851e33b.png
# Skipping existing file: ./train_images_resized\26453eb7e989.png
# Skipping existing file: ./train_images_resized\26463a5fb949.png
# Skipping existing file: ./train_images_resized\2665f72e2dd3.png
# Skipping existing file: ./train_images_resized\266fbefa58fb.png
# Skipping existing file: ./train_images_resized\2682e6da9050.png
# Skipping existing file: ./train_images_resized\26999ebc21de.png
# Skipping existing file: ./train_images_resized\269b44e628eb.png
# Skipping existing file: ./train_images_resized\269f0792f11f.png
# Skipping existing file: ./train_images_resized\26cd40b57ad1.png
# Skipping existing file: ./train_images_resized\26d60db3bbfd.png
# Skipping existing file: ./train_images_resized\26d9576e8043.png
# Skipping existing file: ./train_images_resized\26e231747848.png
# Skipping existing file: ./train_images_resized\26fc2358a38d.png
# Skipping existing file: ./train_images_resized\2700754f71e9.png
# Skipping existing file: ./train_images_resized\272d9c043c81.png
# Skipping existing file: ./train_images_resized\2735be026d44.png
# Skipping existing file: ./train_images_resized\274f4de2a59d.png
# Skipping existing file: ./train_images_resized\274f5029189b.png
# Skipping existing file: ./train_images_resized\276b14f72328.png
# Skipping existing file: ./train_images_resized\2776d70724d3.png
# Skipping existing file: ./train_images_resized\278aa860dffd.png
# Skipping existing file: ./train_images_resized\27933cdbe0cc.png
# Skipping existing file: ./train_images_resized\27b68863349f.png
# Skipping existing file: ./train_images_resized\27bab1432f61.png
# Skipping existing file: ./train_images_resized\27e2be850a99.png
# Skipping existing file: ./train_images_resized\27e4c800a449.png
# Skipping existing file: ./train_images_resized\27f82ada84ac.png
# Skipping existing file: ./train_images_resized\27fca9f12b3c.png
# Skipping existing file: ./train_images_resized\281d7b7c7676.png
# Skipping existing file: ./train_images_resized\2821998fc002.png
# Skipping existing file: ./train_images_resized\282bc792d23a.png
# Skipping existing file: ./train_images_resized\283c3aeba594.png
# Skipping existing file: ./train_images_resized\28503940d10b.png
# Skipping existing file: ./train_images_resized\286e9981dd9b.png
# Skipping existing file: ./train_images_resized\28751f290ba3.png
# Skipping existing file: ./train_images_resized\28824d12d31d.png
# Skipping existing file: ./train_images_resized\289a47dcbb82.png
# Skipping existing file: ./train_images_resized\28a4d00927b7.png
# Skipping existing file: ./train_images_resized\28dc010a0780.png
# Skipping existing file: ./train_images_resized\28f73575e1f2.png
# Skipping existing file: ./train_images_resized\28f93cad89c5.png
# Skipping existing file: ./train_images_resized\28f98cfe3858.png
# Skipping existing file: ./train_images_resized\290ecdba359f.png
# Skipping existing file: ./train_images_resized\29192375ab1b.png
# Skipping existing file: ./train_images_resized\291e2ff3d834.png
# Skipping existing file: ./train_images_resized\291f581d365e.png
# Skipping existing file: ./train_images_resized\2923971566fe.png
# Skipping existing file: ./train_images_resized\2927665214e1.png
# Skipping existing file: ./train_images_resized\29580bed2f7d.png
# Skipping existing file: ./train_images_resized\295fdc964f6e.png
# Skipping existing file: ./train_images_resized\2967e578939f.png
# Skipping existing file: ./train_images_resized\2974c6ad1d58.png
# Skipping existing file: ./train_images_resized\299086c6d1b5.png
# Skipping existing file: ./train_images_resized\2994f17f58a5.png
# Skipping existing file: ./train_images_resized\29a13e666266.png
# Skipping existing file: ./train_images_resized\29b52f64d2db.png
# Skipping existing file: ./train_images_resized\29bc0e721cfe.png
# Skipping existing file: ./train_images_resized\29d059522fa1.png
# Skipping existing file: ./train_images_resized\29f44aea93a4.png
# Skipping existing file: ./train_images_resized\29f9e1ac9507.png
# Skipping existing file: ./train_images_resized\2a08ed6bbcbc.png
# Skipping existing file: ./train_images_resized\2a099b247b10.png
# Skipping existing file: ./train_images_resized\2a2274bcb00a.png
# Skipping existing file: ./train_images_resized\2a2a6435f7f3.png
# Skipping existing file: ./train_images_resized\2a3378bcfbcc.png
# Skipping existing file: ./train_images_resized\2a3a1ed1c285.png
# Skipping existing file: ./train_images_resized\2a4520f1f9a3.png
# Skipping existing file: ./train_images_resized\2a47e5b21791.png
# Skipping existing file: ./train_images_resized\2a5a8b744f08.png
# Skipping existing file: ./train_images_resized\2a7373eeb352.png
# Skipping existing file: ./train_images_resized\2a8a9e957a6c.png
# Skipping existing file: ./train_images_resized\2a93334f663a.png
# Skipping existing file: ./train_images_resized\2af1bf226f51.png
# Skipping existing file: ./train_images_resized\2b074afdf626.png
# Skipping existing file: ./train_images_resized\2b07790a2422.png
# Skipping existing file: ./train_images_resized\2b10f138e67d.png
# Skipping existing file: ./train_images_resized\2b21d293fdf2.png
# Skipping existing file: ./train_images_resized\2b2f5a0f880d.png
# Skipping existing file: ./train_images_resized\2b3a4a81d748.png
# Skipping existing file: ./train_images_resized\2b48daf24be0.png
# Skipping existing file: ./train_images_resized\2b4c7b5f1f1e.png
# Skipping existing file: ./train_images_resized\2b5bb6d33959.png
# Skipping existing file: ./train_images_resized\2b88cb6e31cd.png
# Skipping existing file: ./train_images_resized\2ba0b0d9bda2.png
# Skipping existing file: ./train_images_resized\2bb063318cf1.png
# Skipping existing file: ./train_images_resized\2bb3c492d6d3.png
# Skipping existing file: ./train_images_resized\2bbcfdc477db.png
# Skipping existing file: ./train_images_resized\2bbd1f99ecc3.png
# Skipping existing file: ./train_images_resized\2bd4d4fbed5c.png
# Skipping existing file: ./train_images_resized\2c1d5be654dd.png
# Skipping existing file: ./train_images_resized\2c2aa057afc5.png
# Skipping existing file: ./train_images_resized\2c77bf969079.png
# Skipping existing file: ./train_images_resized\2c8101f14723.png
# Skipping existing file: ./train_images_resized\2c827005b8f8.png
# Skipping existing file: ./train_images_resized\2c9dfc270f1b.png
# Skipping existing file: ./train_images_resized\2cacdb0dffae.png
# Skipping existing file: ./train_images_resized\2cbfc6182ba2.png
# Skipping existing file: ./train_images_resized\2cceb07ff706.png
# Skipping existing file: ./train_images_resized\2cdcc910778d.png
# Skipping existing file: ./train_images_resized\2cef97083e6f.png
# Skipping existing file: ./train_images_resized\2cf18033da31.png
# Skipping existing file: ./train_images_resized\2cfe8703f265.png
# Skipping existing file: ./train_images_resized\2d04cead4d3a.png
# Skipping existing file: ./train_images_resized\2d07162a13b1.png
# Skipping existing file: ./train_images_resized\2d3f4094c08a.png
# Skipping existing file: ./train_images_resized\2d552318eb07.png
# Skipping existing file: ./train_images_resized\2d558de2cabe.png
# Skipping existing file: ./train_images_resized\2d7666b8884f.png
# Skipping existing file: ./train_images_resized\2d870833c0c9.png
# Skipping existing file: ./train_images_resized\2d9d97a6e713.png
# Skipping existing file: ./train_images_resized\2da82d14e1b7.png
# Skipping existing file: ./train_images_resized\2db0cd3e30da.png
# Skipping existing file: ./train_images_resized\2dc647e00ad3.png
# Skipping existing file: ./train_images_resized\2dd28ac497d2.png
# Skipping existing file: ./train_images_resized\2df07eb5779f.png
# Skipping existing file: ./train_images_resized\2e26762daed5.png
# Skipping existing file: ./train_images_resized\2e79041ef722.png
# Skipping existing file: ./train_images_resized\2eba4279e503.png
# Skipping existing file: ./train_images_resized\2ecbc2e3f239.png
# Skipping existing file: ./train_images_resized\2ef10194e80d.png
# Skipping existing file: ./train_images_resized\2ef4a04aed1b.png
# Skipping existing file: ./train_images_resized\2ef955d6d9ff.png
# Skipping existing file: ./train_images_resized\2f143453bb71.png
# Skipping existing file: ./train_images_resized\2f284b6a1940.png
# Skipping existing file: ./train_images_resized\2f2e1949ad56.png
# Skipping existing file: ./train_images_resized\2f42e20db938.png
# Skipping existing file: ./train_images_resized\2f4e81787d9b.png
# Skipping existing file: ./train_images_resized\2f5c9cdfb333.png
# Skipping existing file: ./train_images_resized\2f7789c1e046.png
# Skipping existing file: ./train_images_resized\2f7fbdcc9a4b.png
# Skipping existing file: ./train_images_resized\2f81ee5f2926.png
# Skipping existing file: ./train_images_resized\2f8d14a7d390.png
# Skipping existing file: ./train_images_resized\2f9b66784109.png
# Skipping existing file: ./train_images_resized\2fb3a8606a77.png
# Skipping existing file: ./train_images_resized\2fde69f20585.png
# Skipping existing file: ./train_images_resized\2fdfb80ea53c.png
# Skipping existing file: ./train_images_resized\2fdffb6160a6.png
# Skipping existing file: ./train_images_resized\2fe06bedb2c4.png
# Skipping existing file: ./train_images_resized\2fefb720869a.png
# Skipping existing file: ./train_images_resized\300305ce82d2.png
# Skipping existing file: ./train_images_resized\30263a7d5609.png
# Skipping existing file: ./train_images_resized\302bcdb635ff.png
# Skipping existing file: ./train_images_resized\3044022c6969.png
# Skipping existing file: ./train_images_resized\306c841af3fc.png
# Skipping existing file: ./train_images_resized\3079490a4b9c.png
# Skipping existing file: ./train_images_resized\308f7fce6f0d.png
# Skipping existing file: ./train_images_resized\30941b65348b.png
# Skipping existing file: ./train_images_resized\30cab14951ac.png
# Skipping existing file: ./train_images_resized\30db694bee42.png
# Skipping existing file: ./train_images_resized\310c27067ac0.png
# Skipping existing file: ./train_images_resized\312694ea8e6a.png
# Skipping existing file: ./train_images_resized\3128eb593012.png
# Skipping existing file: ./train_images_resized\3132556f5352.png
# Skipping existing file: ./train_images_resized\31360e44ac64.png
# Skipping existing file: ./train_images_resized\31452ad8808c.png
# Skipping existing file: ./train_images_resized\314862758acf.png
# Skipping existing file: ./train_images_resized\315c1a0d87fd.png
# Skipping existing file: ./train_images_resized\31616ff6b53b.png
# Skipping existing file: ./train_images_resized\3178559fbf57.png
# Skipping existing file: ./train_images_resized\318eb706a134.png
# Skipping existing file: ./train_images_resized\31b5d6fb0256.png
# Skipping existing file: ./train_images_resized\31cb39681f6a.png
# Skipping existing file: ./train_images_resized\3206171db5be.png
# Skipping existing file: ./train_images_resized\3218a6d8eb2c.png
# Skipping existing file: ./train_images_resized\3232b34cbe99.png
# Skipping existing file: ./train_images_resized\3246f07e65b4.png
# Skipping existing file: ./train_images_resized\3254e48c8aa0.png
# Skipping existing file: ./train_images_resized\3286073a976e.png
# Skipping existing file: ./train_images_resized\328d141ed3aa.png
# Skipping existing file: ./train_images_resized\32a3eb37ff40.png
# Skipping existing file: ./train_images_resized\32d7d360d891.png
# Skipping existing file: ./train_images_resized\32ed318235b8.png
# Skipping existing file: ./train_images_resized\33105f9b3a04.png
# Skipping existing file: ./train_images_resized\331121c65e88.png
# Skipping existing file: ./train_images_resized\331b87d1b9d1.png
# Skipping existing file: ./train_images_resized\3323fd59782e.png
# Skipping existing file: ./train_images_resized\3325b1fe55d2.png
# Skipping existing file: ./train_images_resized\33596a635b53.png
# Skipping existing file: ./train_images_resized\33778d136069.png
# Skipping existing file: ./train_images_resized\338326891d84.png
# Skipping existing file: ./train_images_resized\33b893e18eb3.png
# Skipping existing file: ./train_images_resized\33b91def2035.png
# Skipping existing file: ./train_images_resized\33b978734eab.png
# Skipping existing file: ./train_images_resized\33d72035c27a.png
# Skipping existing file: ./train_images_resized\33e7bf536fc5.png
# Skipping existing file: ./train_images_resized\33e8e26a75d4.png
# Skipping existing file: ./train_images_resized\33ffddea8c6e.png
# Skipping existing file: ./train_images_resized\3402124408ea.png
# Skipping existing file: ./train_images_resized\3428230bf1bd.png
# Skipping existing file: ./train_images_resized\342edf9b889d.png
# Skipping existing file: ./train_images_resized\3435fd8675a2.png
# Skipping existing file: ./train_images_resized\345b1f0abbba.png
# Skipping existing file: ./train_images_resized\3461dc601cc2.png
# Skipping existing file: ./train_images_resized\34723fae6475.png
# Skipping existing file: ./train_images_resized\348598d01e18.png
# Skipping existing file: ./train_images_resized\3486f7096276.png
# Skipping existing file: ./train_images_resized\349f3c0ac83e.png
# Skipping existing file: ./train_images_resized\34a7dbd3f05c.png
# Skipping existing file: ./train_images_resized\34acae864963.png
# Skipping existing file: ./train_images_resized\351e842842a2.png
# Skipping existing file: ./train_images_resized\352e4a939242.png
# Skipping existing file: ./train_images_resized\35362d43e753.png
# Skipping existing file: ./train_images_resized\354b8911d6ed.png
# Skipping existing file: ./train_images_resized\356304d15a5c.png
# Skipping existing file: ./train_images_resized\35777eb7859d.png
# Skipping existing file: ./train_images_resized\357f02a779d7.png
# Skipping existing file: ./train_images_resized\3580a545016d.png
# Skipping existing file: ./train_images_resized\358d2224de73.png
# Skipping existing file: ./train_images_resized\3599029efeb3.png
# Skipping existing file: ./train_images_resized\359bab5d784b.png
# Skipping existing file: ./train_images_resized\35aa7f5c2ec0.png
# ...
# Skipping existing file: ./test_images_resized_preprocessed\e74f1fdebdd6.png
# Skipping existing file: ./test_images_resized_preprocessed\e752f13c725c.png
# Skipping existing file: ./test_images_resized_preprocessed\e754bdc1061b.png
# Skipping existing file: ./test_images_resized_preprocessed\e7557ee92477.png
# Skipping existing file: ./test_images_resized_preprocessed\e7655ce118ad.png
# Skipping existing file: ./test_images_resized_preprocessed\e7a9e0ecdd65.png
# Skipping existing file: ./test_images_resized_preprocessed\e7c6e71e699a.png
# Skipping existing file: ./test_images_resized_preprocessed\e7f566b79edd.png
# Skipping existing file: ./test_images_resized_preprocessed\e87155449e8c.png
# Skipping existing file: ./test_images_resized_preprocessed\e87e6e5db799.png
# Skipping existing file: ./test_images_resized_preprocessed\e8c65c471b92.png
# Skipping existing file: ./test_images_resized_preprocessed\e8d83190b171.png
# Skipping existing file: ./test_images_resized_preprocessed\e8deb6e2de83.png
# Skipping existing file: ./test_images_resized_preprocessed\e8efde11fae0.png
# Skipping existing file: ./test_images_resized_preprocessed\e8fd593892f7.png
# Skipping existing file: ./test_images_resized_preprocessed\e9602a2d3044.png
# Skipping existing file: ./test_images_resized_preprocessed\e97517f83449.png
# Skipping existing file: ./test_images_resized_preprocessed\e976cf76fe42.png
# Skipping existing file: ./test_images_resized_preprocessed\e982c6b5b726.png
# Skipping existing file: ./test_images_resized_preprocessed\e999c64033df.png
# Skipping existing file: ./test_images_resized_preprocessed\e99e5a0b8755.png
# Skipping existing file: ./test_images_resized_preprocessed\ea35436c0b08.png
# Skipping existing file: ./test_images_resized_preprocessed\ea4a8d1b2358.png
# Skipping existing file: ./test_images_resized_preprocessed\ea58b230f540.png
# Skipping existing file: ./test_images_resized_preprocessed\ea6742795adc.png
# Skipping existing file: ./test_images_resized_preprocessed\ea746a0d54ac.png
# Skipping existing file: ./test_images_resized_preprocessed\ea8e9a3144e0.png
# Skipping existing file: ./test_images_resized_preprocessed\eaa11b9fd165.png
# Skipping existing file: ./test_images_resized_preprocessed\eab2934c55e1.png
# Skipping existing file: ./test_images_resized_preprocessed\ead743033ad9.png
# Skipping existing file: ./test_images_resized_preprocessed\eb2ca71ecf29.png
# Skipping existing file: ./test_images_resized_preprocessed\eb470f336ee2.png
# Skipping existing file: ./test_images_resized_preprocessed\eb56559c9a8c.png
# Skipping existing file: ./test_images_resized_preprocessed\eba177d4e30e.png
# Skipping existing file: ./test_images_resized_preprocessed\ebb40c984d56.png
# Skipping existing file: ./test_images_resized_preprocessed\ebb70180b81a.png
# Skipping existing file: ./test_images_resized_preprocessed\ec1ec61a3354.png
# Skipping existing file: ./test_images_resized_preprocessed\ec248c3ecd10.png
# Skipping existing file: ./test_images_resized_preprocessed\ec353d42359d.png
# Skipping existing file: ./test_images_resized_preprocessed\ec4309136788.png
# Skipping existing file: ./test_images_resized_preprocessed\ec5b8792b1a2.png
# Skipping existing file: ./test_images_resized_preprocessed\ec71f67e2cd1.png
# Skipping existing file: ./test_images_resized_preprocessed\ec727873cdb7.png
# Skipping existing file: ./test_images_resized_preprocessed\ec8f3ec97245.png
# Skipping existing file: ./test_images_resized_preprocessed\ed0ccec62a3a.png
# Skipping existing file: ./test_images_resized_preprocessed\ed59b7d44223.png
# Skipping existing file: ./test_images_resized_preprocessed\edae318f4942.png
# Skipping existing file: ./test_images_resized_preprocessed\edca22bdbeeb.png
# Skipping existing file: ./test_images_resized_preprocessed\edd6984490a2.png
# Skipping existing file: ./test_images_resized_preprocessed\edd7e3e814e8.png
# Skipping existing file: ./test_images_resized_preprocessed\ede39fdf8477.png
# Skipping existing file: ./test_images_resized_preprocessed\edeccdfdfdf9.png
# Skipping existing file: ./test_images_resized_preprocessed\ee506d853270.png
# Skipping existing file: ./test_images_resized_preprocessed\ee544d980b5e.png
# Skipping existing file: ./test_images_resized_preprocessed\ee6e56f02740.png
# Skipping existing file: ./test_images_resized_preprocessed\ee76112096cf.png
# Skipping existing file: ./test_images_resized_preprocessed\ee969c006782.png
# Skipping existing file: ./test_images_resized_preprocessed\ee98121d0c5a.png
# Skipping existing file: ./test_images_resized_preprocessed\ee9d64c9be0a.png
# Skipping existing file: ./test_images_resized_preprocessed\eea7f3cdc9dd.png
# Skipping existing file: ./test_images_resized_preprocessed\eee06cf50cff.png
# Skipping existing file: ./test_images_resized_preprocessed\ef10428bec8e.png
# Skipping existing file: ./test_images_resized_preprocessed\ef1548136b3f.png
# Skipping existing file: ./test_images_resized_preprocessed\ef36cbd84301.png
# Skipping existing file: ./test_images_resized_preprocessed\ef39106db910.png
# Skipping existing file: ./test_images_resized_preprocessed\ef44b0f4d553.png
# Skipping existing file: ./test_images_resized_preprocessed\ef49726b8df9.png
# Skipping existing file: ./test_images_resized_preprocessed\ef4c7035ce6e.png
# Skipping existing file: ./test_images_resized_preprocessed\ef514c87f4ec.png
# Skipping existing file: ./test_images_resized_preprocessed\ef5f4ffdd75c.png
# Skipping existing file: ./test_images_resized_preprocessed\ef8c405f0c7b.png
# Skipping existing file: ./test_images_resized_preprocessed\f04b0e450206.png
# Skipping existing file: ./test_images_resized_preprocessed\f059ab26d40a.png
# Skipping existing file: ./test_images_resized_preprocessed\f07ca35b523b.png
# Skipping existing file: ./test_images_resized_preprocessed\f0848f9ccf92.png
# Skipping existing file: ./test_images_resized_preprocessed\f08c01a8a480.png
# Skipping existing file: ./test_images_resized_preprocessed\f092448b6617.png
# Skipping existing file: ./test_images_resized_preprocessed\f0a4b6713914.png
# Skipping existing file: ./test_images_resized_preprocessed\f0d3048b5a3f.png
# Skipping existing file: ./test_images_resized_preprocessed\f0e6fd9a71d8.png
# Skipping existing file: ./test_images_resized_preprocessed\f0fe049d478b.png
# Skipping existing file: ./test_images_resized_preprocessed\f10e7a05264b.png
# Skipping existing file: ./test_images_resized_preprocessed\f1178112a435.png
# Skipping existing file: ./test_images_resized_preprocessed\f1416b6ac0f0.png
# Skipping existing file: ./test_images_resized_preprocessed\f1541578ba01.png
# Skipping existing file: ./test_images_resized_preprocessed\f15d74f144a9.png
# Skipping existing file: ./test_images_resized_preprocessed\f167245c0bdf.png
# Skipping existing file: ./test_images_resized_preprocessed\f1fe9471fc83.png
# Skipping existing file: ./test_images_resized_preprocessed\f218a44247b1.png
# Skipping existing file: ./test_images_resized_preprocessed\f2320b9e1197.png
# Skipping existing file: ./test_images_resized_preprocessed\f237bd2d4189.png
# Skipping existing file: ./test_images_resized_preprocessed\f3135d8ed877.png
# Skipping existing file: ./test_images_resized_preprocessed\f320b5f7f5b5.png
# Skipping existing file: ./test_images_resized_preprocessed\f32613d8dd7f.png
# Skipping existing file: ./test_images_resized_preprocessed\f32bdf2a84ec.png
# Skipping existing file: ./test_images_resized_preprocessed\f32e563daf7b.png
# Skipping existing file: ./test_images_resized_preprocessed\f360627bb76b.png
# Skipping existing file: ./test_images_resized_preprocessed\f36969f69b4f.png
# Skipping existing file: ./test_images_resized_preprocessed\f39ce81e62e4.png
# Skipping existing file: ./test_images_resized_preprocessed\f3a6c7df5fdc.png
# Skipping existing file: ./test_images_resized_preprocessed\f3bebccd8f01.png
# Skipping existing file: ./test_images_resized_preprocessed\f3bf83a0e378.png
# Skipping existing file: ./test_images_resized_preprocessed\f3d95fad170c.png
# Skipping existing file: ./test_images_resized_preprocessed\f3daf369a103.png
# Skipping existing file: ./test_images_resized_preprocessed\f3e5159e0b2d.png
# Skipping existing file: ./test_images_resized_preprocessed\f3f696c65bfd.png
# Skipping existing file: ./test_images_resized_preprocessed\f41ef796cc0d.png
# Skipping existing file: ./test_images_resized_preprocessed\f443c3d7ab22.png
# Skipping existing file: ./test_images_resized_preprocessed\f444cd113883.png
# Skipping existing file: ./test_images_resized_preprocessed\f44fd938c664.png
# Skipping existing file: ./test_images_resized_preprocessed\f45ceb654c4d.png
# Skipping existing file: ./test_images_resized_preprocessed\f47c5fc86387.png
# Skipping existing file: ./test_images_resized_preprocessed\f4a37bac1050.png
# Skipping existing file: ./test_images_resized_preprocessed\f506b2b3c950.png
# Skipping existing file: ./test_images_resized_preprocessed\f524093e34ea.png
# Skipping existing file: ./test_images_resized_preprocessed\f526c7a16749.png
# Skipping existing file: ./test_images_resized_preprocessed\f535da2b9102.png
# Skipping existing file: ./test_images_resized_preprocessed\f543269b7905.png
# Skipping existing file: ./test_images_resized_preprocessed\f54b2ebf7f43.png
# Skipping existing file: ./test_images_resized_preprocessed\f576e224de55.png
# Skipping existing file: ./test_images_resized_preprocessed\f5aa838e2ffc.png
# Skipping existing file: ./test_images_resized_preprocessed\f5b4f7bc69e7.png
# Skipping existing file: ./test_images_resized_preprocessed\f5ebdedbba98.png
# Skipping existing file: ./test_images_resized_preprocessed\f636fc9e4355.png
# Skipping existing file: ./test_images_resized_preprocessed\f6578f3dfafe.png
# Skipping existing file: ./test_images_resized_preprocessed\f68ada6a0892.png
# Skipping existing file: ./test_images_resized_preprocessed\f6a79dbb4339.png
# Skipping existing file: ./test_images_resized_preprocessed\f6a9c937e6d6.png
# Skipping existing file: ./test_images_resized_preprocessed\f7113d580492.png
# Skipping existing file: ./test_images_resized_preprocessed\f72a18c76408.png
# Skipping existing file: ./test_images_resized_preprocessed\f73e8ec73179.png
# Skipping existing file: ./test_images_resized_preprocessed\f756b1c4c52b.png
# Skipping existing file: ./test_images_resized_preprocessed\f75b65c8cc4c.png
# Skipping existing file: ./test_images_resized_preprocessed\f785337edf07.png
# Skipping existing file: ./test_images_resized_preprocessed\f7b4b4cf9161.png
# Skipping existing file: ./test_images_resized_preprocessed\f7b5f3581d20.png
# Skipping existing file: ./test_images_resized_preprocessed\f7cb2e6212b2.png
# Skipping existing file: ./test_images_resized_preprocessed\f7dd2700a3d5.png
# Skipping existing file: ./test_images_resized_preprocessed\f7de9615aea3.png
# Skipping existing file: ./test_images_resized_preprocessed\f7f026a5a4bb.png
# Skipping existing file: ./test_images_resized_preprocessed\f7f8dd6cd6bd.png
# Skipping existing file: ./test_images_resized_preprocessed\f85bf43b7e05.png
# Skipping existing file: ./test_images_resized_preprocessed\f893813ed0d4.png
# Skipping existing file: ./test_images_resized_preprocessed\f898d3e8ed90.png
# Skipping existing file: ./test_images_resized_preprocessed\f8aa9af6ca63.png
# Skipping existing file: ./test_images_resized_preprocessed\f8b184ad0701.png
# Skipping existing file: ./test_images_resized_preprocessed\f8b9c9f5235f.png
# Skipping existing file: ./test_images_resized_preprocessed\f8f530fa573e.png
# Skipping existing file: ./test_images_resized_preprocessed\f9642cf6a5bb.png
# Skipping existing file: ./test_images_resized_preprocessed\f96f06803471.png
# Skipping existing file: ./test_images_resized_preprocessed\f96fecb16957.png
# Skipping existing file: ./test_images_resized_preprocessed\f99a9ad63dda.png
# Skipping existing file: ./test_images_resized_preprocessed\f9e7f614c91d.png
# Skipping existing file: ./test_images_resized_preprocessed\f9f1cd9ed16c.png
# Skipping existing file: ./test_images_resized_preprocessed\f9f3d97f3269.png
# Skipping existing file: ./test_images_resized_preprocessed\fa007743976a.png
# Skipping existing file: ./test_images_resized_preprocessed\fa09c97a2887.png
# Skipping existing file: ./test_images_resized_preprocessed\fa7a97f4de76.png
# Skipping existing file: ./test_images_resized_preprocessed\fa8b04533b99.png
# Skipping existing file: ./test_images_resized_preprocessed\fa98490bc13c.png
# Skipping existing file: ./test_images_resized_preprocessed\fa988ad2271e.png
# Skipping existing file: ./test_images_resized_preprocessed\fab7d8e8a1fa.png
# Skipping existing file: ./test_images_resized_preprocessed\fac5beea82bd.png
# Skipping existing file: ./test_images_resized_preprocessed\fb2d29623cfc.png
# Skipping existing file: ./test_images_resized_preprocessed\fb5b3c8d9cbb.png
# Skipping existing file: ./test_images_resized_preprocessed\fb75ed010413.png
# Skipping existing file: ./test_images_resized_preprocessed\fbb5cb3a2222.png
# Skipping existing file: ./test_images_resized_preprocessed\fbc502a64901.png
# Skipping existing file: ./test_images_resized_preprocessed\fbc8b60526f1.png
# Skipping existing file: ./test_images_resized_preprocessed\fbcd28a51ef7.png
# Skipping existing file: ./test_images_resized_preprocessed\fbe36fdd76be.png
# Skipping existing file: ./test_images_resized_preprocessed\fc3935afc788.png
# Skipping existing file: ./test_images_resized_preprocessed\fc44a4ffaa45.png
# Skipping existing file: ./test_images_resized_preprocessed\fc5ea7f74c48.png
# Skipping existing file: ./test_images_resized_preprocessed\fc66648f758e.png
# Skipping existing file: ./test_images_resized_preprocessed\fc67df1e574e.png
# Skipping existing file: ./test_images_resized_preprocessed\fc6c9d0efe53.png
# Skipping existing file: ./test_images_resized_preprocessed\fc79feb5deed.png
# Skipping existing file: ./test_images_resized_preprocessed\fcbc1f4b5342.png
# Skipping existing file: ./test_images_resized_preprocessed\fcd166e6e4b5.png
# Skipping existing file: ./test_images_resized_preprocessed\fcea00df9f33.png
# Skipping existing file: ./test_images_resized_preprocessed\fd2978398705.png
# Skipping existing file: ./test_images_resized_preprocessed\fd2d58c6cd45.png
# Skipping existing file: ./test_images_resized_preprocessed\fd4d81b43e84.png
# Skipping existing file: ./test_images_resized_preprocessed\fd7cc592106e.png
# Skipping existing file: ./test_images_resized_preprocessed\fd8e6b0b2e45.png
# Skipping existing file: ./test_images_resized_preprocessed\fda8612fcc8c.png
# Skipping existing file: ./test_images_resized_preprocessed\fdde61dd1bde.png
# Skipping existing file: ./test_images_resized_preprocessed\fde8778182af.png
# Skipping existing file: ./test_images_resized_preprocessed\fe0a340c4477.png
# Skipping existing file: ./test_images_resized_preprocessed\fe190d618acf.png
# Skipping existing file: ./test_images_resized_preprocessed\fe1d2f703efc.png
# Skipping existing file: ./test_images_resized_preprocessed\fe5618ad2460.png
# Skipping existing file: ./test_images_resized_preprocessed\fe57ff56618e.png
# Skipping existing file: ./test_images_resized_preprocessed\fe84ad1df04b.png
# Skipping existing file: ./test_images_resized_preprocessed\fe920e47b72d.png
# Skipping existing file: ./test_images_resized_preprocessed\fed9d587f158.png
# Skipping existing file: ./test_images_resized_preprocessed\fee5bd042c3b.png
# Skipping existing file: ./test_images_resized_preprocessed\fef8e645d030.png
# Skipping existing file: ./test_images_resized_preprocessed\ff2fd94448de.png
# Skipping existing file: ./test_images_resized_preprocessed\ff4c945d9b17.png
# Skipping existing file: ./test_images_resized_preprocessed\ff64897ac0d8.png
# Skipping existing file: ./test_images_resized_preprocessed\ffa73465b705.png
# Skipping existing file: ./test_images_resized_preprocessed\ffdc2152d455.png
#         id_code                       file_path         file_name
# 0  0005cfc8afb6  ./test_images/0005cfc8afb6.png  0005cfc8afb6.png
# 1  003f0afdcd15  ./test_images/003f0afdcd15.png  003f0afdcd15.png
# 2  006efc72b638  ./test_images/006efc72b638.png  006efc72b638.png
# 3  00836aaacf06  ./test_images/00836aaacf06.png  00836aaacf06.png
# 4  009245722fa4  ./test_images/009245722fa4.png  009245722fa4.png
# 5  009c019a7309  ./test_images/009c019a7309.png  009c019a7309.png

# %%
df_train_train,df_train_valid = train_test_split(df_train,test_size = 0.2)
print(df_train_train.shape,df_train_valid.shape)
df_train_train.head(6)
# Out:
# (2929, 4) (733, 4)
#            id_code diagnosis                        file_path  \
# 1431  64b9206afb3f         0  ./train_images/64b9206afb3f.png
# 3465  f080a22008be         3  ./train_images/f080a22008be.png
# 2373  a64273801bde         2  ./train_images/a64273801bde.png
# 3116  d871895742b1         0  ./train_images/d871895742b1.png
# 139   0a61bddab956         1  ./train_images/0a61bddab956.png
# 2495  ad1aa75d5630         0  ./train_images/ad1aa75d5630.png
#
#              file_name
# 1431  64b9206afb3f.png
# 3465  f080a22008be.png
# 2373  a64273801bde.png
# 3116  d871895742b1.png
# 139   0a61bddab956.png
# 2495  ad1aa75d5630.png

# %%
N_CLASSES = df_train_train['diagnosis'].nunique()

# %%
#initalise the generators 
train_generator, valid_generator, test_generator = img_generator(df_train, df_test)
# Out:
# Found 2930 validated image filenames belonging to 5 classes.
# Found 732 validated image filenames belonging to 5 classes.
# Found 1928 validated image filenames.

# %%
#create the model
model = create_model(input_shape=(HEIGHT, WIDTH, CANAL), n_out=N_CLASSES)

for layer in model.layers:
    layer.trainable = False

for i in range(-5, 0):
    model.layers[i].trainable = True
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 326, 326,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 160, 160,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 160, 160,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 160, 160,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 162, 162,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 80, 80,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 80, 80,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 80, 80,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 80, 80,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 80, 80,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 80, 80,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 80, 80,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 80, 80,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 80, 80,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 80, 80,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 80, 80,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 80, 80,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 80, 80,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 80, 80,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 80, 80,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 80, 80,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 80, 80,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 80, 80,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 80, 80,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 80, 80,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 80, 80,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 80, 80,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 80, 80,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 80, 80,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 40, 40,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 40, 40,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 40, 40,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 40, 40,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 40, 40,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 40, 40,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 40, 40,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 40, 40,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 40, 40,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 40, 40,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 40, 40,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 40, 40,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 40, 40,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 40, 40,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 40, 40,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 40, 40,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 40, 40,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 40, 40,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 40, 40,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 40, 40,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 40, 40,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 40, 40,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 40, 40,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 40, 40,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 40, 40,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 40, 40,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 40, 40,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 20, 20,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 20, 20,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 20, 20,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 20, 20,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 20, 20,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 20, 20,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 20, 20,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 20, 20,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 20, 20,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 20, 20,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 20, 20,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 20, 20,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 20, 20,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 20, 20,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 20, 20,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 20, 20,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 20, 20,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 20, 20,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 20, 20,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 20, 20,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 20, 20,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 20, 20,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 20, 20,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 20, 20,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 20, 20,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 20, 20,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 20, 20,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 10, 10,    │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 10, 10,    │          0 │ conv5_block1_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 10, 10,    │          0 │ conv5_block1_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 10, 10,    │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 10, 10,    │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 10, 10,    │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 10, 10,    │          0 │ conv5_block2_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 10, 10,    │          0 │ conv5_block2_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 10, 10,    │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 10, 10,    │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 10, 10,    │          0 │ conv5_block3_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 10, 10,    │          0 │ conv5_block3_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 10, 10,    │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 10, 10,    │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  4,196,352 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2048)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, 5)         │     10,245 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,794,309 (106.03 MB)
#  Trainable params: 4,206,597 (16.05 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
print(STEP_SIZE_TRAIN,STEP_SIZE_VALID)
# Out:
# 366 91

# %%
# Run some warm up epochs 
model.compile(optimizer=optimizers.Adam(learning_rate=WARMUP_LEARNING_RATE), loss='categorical_crossentropy', metrics=['accuracy'])

history_warmup = model.fit(train_generator,
                           steps_per_epoch=STEP_SIZE_TRAIN,
                           validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                           epochs=WARMUP_EPOCHS,
                           verbose=1).history
# Out:
# Epoch 1/2
# C:\Users\micha\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.3668 - loss: 2.3433 - val_accuracy: 0.4629 - val_loss: 1.3289
# Epoch 2/2
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 4:12 693ms/step - accuracy: 0.2500 - loss: 1.5137
# c:\Program Files\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2500 - loss: 0.7589 - val_accuracy: 0.0000e+00 - val_loss: 1.0466

# %%
for layer in model.layers:
    layer.trainable = True

# Create callback which will make sure the training will stop when the best accuracy is achieved through the training
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
# This specific callback will save the model's best accuracy
savepoint = ModelCheckpoint("test_best_model.keras", monitor='loss', verbose=1, save_best_only=True, mode='auto')

callback_list = [es, rlrop, savepoint]
optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
# Initialize the model before running the training
model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 320, 320,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 326, 326,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 160, 160,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 160, 160,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 160, 160,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 162, 162,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 80, 80,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 80, 80,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 80, 80,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 80, 80,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 80, 80,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 80, 80,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 80, 80,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 80, 80,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 80, 80,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 80, 80,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 80, 80,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 80, 80,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 80, 80,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 80, 80,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 80, 80,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 80, 80,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 80, 80,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 80, 80,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 80, 80,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 80, 80,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 80, 80,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 80, 80,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 80, 80,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 80, 80,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 80, 80,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 80, 80,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 80, 80,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 40, 40,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 40, 40,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 40, 40,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 40, 40,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 40, 40,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 40, 40,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 40, 40,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 40, 40,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 40, 40,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 40, 40,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 40, 40,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 40, 40,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 40, 40,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 40, 40,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 40, 40,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 40, 40,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 40, 40,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 40, 40,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 40, 40,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 40, 40,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 40, 40,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 40, 40,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 40, 40,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 40, 40,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 40, 40,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 40, 40,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 40, 40,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 40, 40,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 40, 40,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 40, 40,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 40, 40,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 20, 20,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 20, 20,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 20, 20,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 20, 20,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 20, 20,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 20, 20,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 20, 20,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 20, 20,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 20, 20,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 20, 20,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 20, 20,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 20, 20,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 20, 20,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 20, 20,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 20, 20,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 20, 20,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 20, 20,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 20, 20,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 20, 20,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 20, 20,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 20, 20,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 20, 20,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 20, 20,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 20, 20,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 20, 20,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 20, 20,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 20, 20,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 20, 20,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 20, 20,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 20, 20,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 20, 20,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 20, 20,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 20, 20,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 10, 10,    │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 10, 10,    │          0 │ conv5_block1_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 10, 10,    │          0 │ conv5_block1_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 10, 10,    │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 10, 10,    │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 10, 10,    │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 10, 10,    │          0 │ conv5_block2_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 10, 10,    │          0 │ conv5_block2_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 10, 10,    │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 10, 10,    │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 10, 10,    │          0 │ conv5_block3_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 10, 10,    │          0 │ conv5_block3_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 10, 10,    │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 10, 10,    │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  4,196,352 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 2048)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, 5)         │     10,245 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,794,309 (106.03 MB)
#  Trainable params: 27,741,189 (105.82 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
#run the training of the model using train_generator , valid_generator and callback_list
history_finetunning = model.fit(train_generator,
                                steps_per_epoch=STEP_SIZE_TRAIN,
                                validation_data=valid_generator,
                                validation_steps=STEP_SIZE_VALID,
                                epochs=EPOCHS,
                                callbacks=callback_list,
                                verbose=1).history

# %%
#the image below shows the progress of accuracy of the model with the training data as well as with the validation data that have never been seen before
plt.figure(figsize=(8,5))

plt.plot(history_finetunning['accuracy'])
plt.plot(history_finetunning['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.gca().ticklabel_format(axis='both', style='plain', useOffset=False)
plt.show()

# %%
#complete generator meaning run predictions of train data to determine accuracy with data familiar to the model and to determine Cohen Kappa Score
complete_datagen = ImageDataGenerator(rescale=1./255)
complete_generator = complete_datagen.flow_from_dataframe(dataframe=df_train_train,
                                                          directory = "./train_images_resized_preprocessed/",
                                                          x_col="file_name",
                                                          target_size=(HEIGHT, WIDTH),
                                                          batch_size=1,
                                                          shuffle=False,
                                                          class_mode=None)

STEP_SIZE_COMPLETE = complete_generator.n//complete_generator.batch_size
train_preds = model.predict_generator(complete_generator, steps=STEP_SIZE_COMPLETE,verbose = 1)
train_preds = [np.argmax(pred) for pred in train_preds]

# %%
#Print the calculated accuracy and the Cohen Kappa score 
print("Train Cohen Kappa score: %.3f" % cohen_kappa_score(train_preds, df_train_train['diagnosis'].astype('int'), weights='quadratic'))
print("Train Accuracy score : %.3f" % accuracy_score(df_train_train['diagnosis'].astype('int'),train_preds))

# %%
#save the model structure 
model.save('model')
